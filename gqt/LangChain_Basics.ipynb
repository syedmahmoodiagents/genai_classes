# %%
# !pip install langchain-huggingface --q

# %%
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

# %%
import os

# %%
os.environ["HF_TOKEN"] = "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1231"

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

# %%
model = ChatHuggingFace(llm=HuggingFaceEndpoint(repo_id="openai/gpt-oss-20b"))

# %%
# model.invoke("what is the capital of France.")
# Out:
# AIMessage(content='The capital of France is **Paris**.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 78, 'total_tokens': 116}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_9321469755', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fef55-08e6-7061-a08e-efead97c36de-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 78, 'output_tokens': 38, 'total_tokens': 116})

# %%
messages = [
    SystemMessage(content="Answer me as how is shown the examples"),

    HumanMessage(content="what is the capital of france."),
    AIMessage(content="Paris Haha"),
    HumanMessage(content="what is the capital of germany?"),
    AIMessage(content="Berlin Haha"),
    HumanMessage(content="what is the capital of spain?"),
    AIMessage(content="Madrid Haha"),
    HumanMessage(content="what is the capital of italy?")
            ]

# %%
resp = model.invoke(messages)

# %%
resp
# Out:
# AIMessage(content='Rome Haha', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 147, 'total_tokens': 230}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_fd1840abb1', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ff43e-e81a-71d0-a5c0-fb96774ea511-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 147, 'output_tokens': 83, 'total_tokens': 230})

# %%
resp.content
# Out:
# 'Rome Haha'

# %%
# ls = []
# ls.append(10)
# ls.append(20)
# ls.append(30)

# %%
mess = []
mess.append(SystemMessage(content="Answer me as how is shown the examples"))
mess.append(HumanMessage(content="what is the capital of france."))
mess.append(AIMessage(content="Paris Haha"))
mess.append(HumanMessage(content="what is the capital of germany?"))
mess.append(AIMessage(content="Berlin Haha"))
mess.append(HumanMessage(content="what is the capital of spain?"))

# %%
# model.invoke(mess)
# Out:
# [SystemMessage(content='Answer me as how is shown the examples', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='what is the capital of france.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Paris Haha', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='what is the capital of germany?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Berlin Haha', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='what is the capital of spain?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# # Lets track the history of prompts

# %%
mod = ChatHuggingFace(llm=HuggingFaceEndpoint(repo_id="openai/gpt-oss-20b"))

# %%
msg = []
msg.append(SystemMessage(content="Answer me in not more than one line"))
msg.append(HumanMessage(content="what is the capital of france."))

# %%
resp = mod.invoke(msg)

# %%
resp
# Out:
# AIMessage(content='Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 59, 'prompt_tokens': 91, 'total_tokens': 150}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_e2cb7a84ec', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ff449-d25e-7252-9eaf-8a5b063f392b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 91, 'output_tokens': 59, 'total_tokens': 150})

# %%
# mod.invoke("what is the main languag of that place")

# %%
resp.content
# Out:
# 'Paris.'

# %%
msg.append(AIMessage(content=resp.content))
msg.append(HumanMessage(content="what is the main language of that place."))

# %%
msg
# Out:
# [SystemMessage(content='Answer me in not more than one line', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='what is the capital of france.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Paris', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='what is the main language of that place.', additional_kwargs={}, response_metadata={})]

# %%
rps = mod.invoke(msg)

# %%
rps
# Out:
# AIMessage(content='French', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 109, 'total_tokens': 163}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_996f667773', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ff44e-8fe2-7932-915f-03bbac8ab364-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 109, 'output_tokens': 54, 'total_tokens': 163})

# %%
msg.append(AIMessage(content=rps.content))
msg.append(HumanMessage(content="what is the name of downtown of that city."))

# %%
mod.invoke(msg)
# Out:
# AIMessage(content='The downtown area of Paris is generally called the **Centre‑ville** (city centre).', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 210, 'prompt_tokens': 130, 'total_tokens': 340}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_587d0d67cc', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ff450-d968-74c2-ac9e-0d50c6981296-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 130, 'output_tokens': 210, 'total_tokens': 340})
